# %%
# !pip install --upgrade -q colabutils

# %%
import requests
import datetime
import time
import json  
import zipfile

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive/')
filename = '/content/drive/My Drive/_temp/Fut6IwLOEQYAICAAAAA30_kBAFBWg3aI' 


d = ""  
data = None  
with zipfile.ZipFile(filename, "r") as z:
   for filename in z.namelist():  
      print(filename)  
      with z.open(filename) as f:  
         data = f.read()  
         d = d+json.dumps(json.loads(data))
         #d = json.loads(data)
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# reports.json
# reports/20.json
# reportElements/20.json
# reportElements/20/1.json
# reportElements/20/99.json
# reportElements/20/2.json
# reportElements/20/4.json
# reportElements/20/19.json
# reportElements/20/8.json
# reportElements/20/21.json
# reportElements/20/23.json
# reportElements/20/42.json
# reportElements/20/47.json
# reportElements/20/95.json
# reportElements/20/50.json
# reportElements/20/51.json
# reportElements/20/52.json
# reportElements/20/53.json
# reportElements/20/54.json
# reportElements/20/98.json
# reportElements/20/58.json
# reportElements/20/59.json
# reportElements/20/60.json
# reportElements/20/61.json
# reportElements/20/62.json
# reportElements/20/64.json
# reportElements/20/65.json
# reportElements/20/66.json
# reportElements/20/67.json
# reportElements/20/68.json
# reportElements/20/96.json
# reportElements/20/97.json
# reportElements/20/69.json
# reportElements/20/86.json
# reportElements/20/100.json
# reportElements/20/116.json
# reportElements/20/3.json
# dataproviders.json
# dataproviders/DP0.json
# dataproviders/DP1.json
# dataproviders/DP2.json

# %%
print(d)
# Out:
# {"reports": {"report": [{"reference": "14.RS", "showDataChanges": "false", "name": "Report 1", "@hasDatafilter": "false", "section": [], "id": 14, "@hasDriller": "false"}, {"reference": "27.RS", "showDataChanges": "false", "name": "Report 2", "@hasDatafilter": "false", "section": [], "id": 27, "@hasDriller": "false"}, {"reference": "48.RS", "showDataChanges": "false", "name": "Report 3", "@hasDatafilter": "false", "section": [], "id": 48, "@hasDriller": "false"}]}}{"report": {"reference": "14.RS", "showDataChanges": "false", "name": "Report 1", "paginationMode": "QuickDisplay", "@hasDatafilter": "false", "section": [], "style": {"hyperLinkColors": {"@link": "#0000ff", "@visited": "#551a8b", "@active": "#000000", "@hover": "#000000"}}, "id": 14, "pageSettings": {"margins": {"@right": 2835, "@bottom": 2835, "@top": 2835, "@left": 2835}, "scaling": {"@factor": 100}, "records": {"@horizontal": 20, "@vertical": 100}, "format": {"@height": 42094, "@width": 29764, "$": "A4", "@orientation": "Portrait", "@papersizeId": "A4"}}, "@hasDriller": "false", "showFolding": "false"}}{"elements": {"element": [{"size": {"@minimalHeight": 1984}, "@type": "PageZone", "name": "Header", "id": 1}, {"@type": "PageZone", "name": "Body", "id": 2}, {"padding": {"@right": 213, "@bottom": 156, "@top": 156, "@left": 213}, "size": {"@minimalWidth": 15048, "@minimalHeight": 1548, "@autofitHeight": "false", "@autofitWidth": "false"}, "@type": "Cell", "id": 4, "position": {"@oneVerticalPage": "false", "@repeatOnEveryVerticalPage": "false", "@x": 7416, "@y": 432, "@verticalAnchorType": "None", "@newHorizontalPage": "false", "@horizontalAnchorType": "None", "@oneHorizontalPage": "false", "@newVerticalPage": "false"}, "parentId": 2}, {"@type": "VTable", "name": "Block 1", "@hasDatafilter": "false", "id": 13, "position": {"@oneVerticalPage": "false", "@repeatOnEveryVerticalPage": "false", "@x": 450, "@y": 900, "@verticalAnchorType": "End", "@verticalAnchorId": 4, "@newHorizontalPage": "false", "@horizontalAnchorType": "None", "@oneHorizontalPage": "false", "@newVerticalPage": "false"}, "parentId": 2}, {"padding": {"@right": 250, "@bottom": 230, "@top": 220, "@left": 250}, "size": {"@minimalWidth": 3005, "@minimalHeight": 567, "@autofitHeight": "true", "@autofitWidth": "false"}, "@type": "Cell", "id": 6, "parentId": 13}, {"padding": {"@right": 250, "@bottom": 230, "@top": 220, "@left": 250}, "size": {"@minimalWidth": 12225, "@minimalHeight": 567, "@autofitHeight": "true", "@autofitWidth": "false"}, "@type": "Cell", "id": 17, "parentId": 13}, {"padding": {"@right": 250, "@bottom": 230, "@top": 220, "@left": 250}, "size": {"@minimalWidth": 7312, "@minimalHeight": 567, "@autofitHeight": "true", "@autofitWidth": "false"}, "@type": "Cell", "id": 19, "parentId": 13}, {"padding": {"@right": 250, "@bottom": 230, "@top": 220, "@left": 250}, "size": {"@minimalWidth": 3005, "@minimalHeight": 567, "@autofitHeight": "true", "@autofitWidth": "true"}, "@type": "Cell", "id": 21, "parentId": 13}, {"padding": {"@right": 250, "@bottom": 350, "@top": 300, "@left": 250}, "size": {"@minimalWidth": 3005, "@minimalHeight": 567, "@autofitHeight": "true", "@autofitWidth": "false"}, "@type": "Cell", "id": 10, "parentId": 13}, {"padding": {"@right": 250, "@bottom": 350, "@top": 300, "@left": 250}, "size": {"@minimalWidth": 12225, "@minimalHeight": 567, "@autofitHeight": "true", "@autofitWidth": "false"}, "@type": "Cell", "id": 18, "parentId": 13}, {"padding": {"@right": 250, "@bottom": 350, "@top": 300, "@left": 250}, "size": {"@minimalWidth": 7312, "@minimalHeight": 567, "@autofitHeight": "true", "@autofitWidth": "false"}, "@type": "Cell", "id": 20, "parentId": 13}, {"padding": {"@right": 250, "@bottom": 350, "@top": 300, "@left": 250}, "size": {"@minimalWidth": 3005, "@minimalHeight": 567, "@autofitHeight": "true", "@autofitWidth": "true"}, "@type": "Cell", "id": 22, "parentId": 13}, {"padding": {"@right": 213, "@bottom": 156, "@top": 156, "@left": 213}, "size": {"@minimalWidth": 23976, "@mi ...

# %%
import pandas as pd 
from pandas.io.json  import json_normalize #package for flattening json in pandas df
nycphil = json_normalize(d['dataprovider'])
nycphil.head(3)
# Out:
#   dataSourcePrefix  ...                       properties.property
# 0              DS0  ...  [{'@key': 'isRefreshable', '$': 'true'}]
#
# [1 rows x 15 columns]
